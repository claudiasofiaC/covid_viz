# %%
import pandas as pd
import geopandas as gpd

# read in csv file from John Hopkins
df = pd.read_csv('time_series_covid19_confirmed_global.csv')

# %%
# !pip install geopandas
# Out:
# ...
#   Using cached geopandas-0.8.1-py2.py3-none-any.whl (962 kB)
# ...
#   Using cached pyproj-3.0.0.post1-cp37-cp37m-macosx_10_9_x86_64.whl (7.4 MB)
# ...
#   Using cached Fiona-1.8.18-cp37-cp37m-macosx_10_9_x86_64.whl (14.8 MB)
# ...
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# ...
#   Using cached cligj-0.7.1-py3-none-any.whl (7.1 kB)
# ...
#   Using cached munch-2.5.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached Shapely-1.7.1-cp37-cp37m-macosx_10_9_x86_64.whl (1.0 MB)
# ...

# %%
# group by country, since we want the entire country and not region by region
df = df.groupby('Country/Region').sum()

# drop lat and long columns
df = df.drop(columns = ['Lat', 'Long'])

# create a transpose of the dataframe
df_trans = df.T
#df_trans.plot(y= ['Mexico', 'US', 'Germany', 'New Zealand'], use_index= True, figsize= (7,7));

# %%
df_trans.head()
# Out:
# Country/Region  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 1/22/20                   0        0        0        0       0
# 1/23/20                   0        0        0        0       0
# 1/24/20                   0        0        0        0       0
# 1/25/20                   0        0        0        0       0
# 1/26/20                   0        0        0        0       0
#
# Country/Region  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  \
# 1/22/20                           0          0        0          0        0
# 1/23/20                           0          0        0          0        0
# 1/24/20                           0          0        0          0        0
# 1/25/20                           0          0        0          0        0
# 1/26/20                           0          0        0          4        0
#
# Country/Region  ...  United Kingdom  Uruguay  Uzbekistan  Vanuatu  Venezuela  \
# ...

# %%
# read in Za Wardu map
world = gpd.read_file('')
world.plot()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: D:\GeoDelta\Dynamic Mapping of COVID-19 Progression\World_Map.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-9-2d26ecca075c> in <module>
#       1 # read in Za Wardu map
# ----> 2 world = gpd.read_file('D:\GeoDelta\Dynamic Mapping of COVID-19 Progression\World_Map.shp')
#       3 world.plot()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#      94
#      95     with fiona_env():
# ---> 96         with reader(path_or_bytes, **kwargs) as features:
# ...
